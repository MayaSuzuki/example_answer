# %%
# %%file 7-10.c
#
# #include<stdio.h>
#
# int main() {
#     int i;
#     float x = 0.0;
#
#     for(i = 0; i <= 100; i++) {
#         printf("x = %f  x = %f\n", x, i / 100.0);
#         x += 0.01;
#     }
#
#     return 0;
# }
# Out:
# Overwriting 7-10.c

# %%
# !gcc 7-10.c -o prog && ./prog
# Out:
# x = 0.000000  x = 0.000000
# x = 0.010000  x = 0.010000
# x = 0.020000  x = 0.020000
# x = 0.030000  x = 0.030000
# x = 0.040000  x = 0.040000
# x = 0.050000  x = 0.050000
# x = 0.060000  x = 0.060000
# x = 0.070000  x = 0.070000
# x = 0.080000  x = 0.080000
# x = 0.090000  x = 0.090000
# x = 0.100000  x = 0.100000
# x = 0.110000  x = 0.110000
# x = 0.120000  x = 0.120000
# x = 0.130000  x = 0.130000
# x = 0.140000  x = 0.140000
# x = 0.150000  x = 0.150000
# x = 0.160000  x = 0.160000
# x = 0.170000  x = 0.170000
# x = 0.180000  x = 0.180000
# x = 0.190000  x = 0.190000
# x = 0.200000  x = 0.200000
# x = 0.210000  x = 0.210000
# x = 0.220000  x = 0.220000
# x = 0.230000  x = 0.230000
# x = 0.240000  x = 0.240000
# x = 0.250000  x = 0.250000
# x = 0.260000  x = 0.260000
# x = 0.270000  x = 0.270000
# x = 0.280000  x = 0.280000
# x = 0.290000  x = 0.290000
# x = 0.300000  x = 0.300000
# x = 0.310000  x = 0.310000
# x = 0.320000  x = 0.320000
# x = 0.330000  x = 0.330000
# ...
